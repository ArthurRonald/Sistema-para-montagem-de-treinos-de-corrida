# %%
from xgboost import XGBClassifier
from sklearn.preprocessing import LabelEncoder
import pandas as pd

df = pd.read_csv("corredores_ficticios.csv")
df.head()
# Out:
#    Usuário Objetivo do treino  Tempo (min)  Distância (km) Histórico de lesão  \
# 0        1      Emagrecimento          118            18.8                Não
# 1        2           Maratona           63             8.0                Não
# 2        3      Emagrecimento           48             6.7                Não
# 3        4      Emagrecimento           78             8.5                Não
# 4        5           Maratona           90            19.7                Não
#
#    Pace (min/km)  Peso (kg)  Altura (cm)  Atividades/semana          Nível
# 0           6.26       79.9        173.0                  6  Intermediário
# 1           7.84       89.0        172.0                  6  Intermediário
# 2           7.14       66.9        175.0                  4  Intermediário
# 3           9.22       69.0        199.0                  2  Intermediário
# 4           4.58       94.4        165.0                  4       Avançado

# %%
encoder1=LabelEncoder()
encoder2=LabelEncoder()
encoder3=LabelEncoder()

df["objetivo_encoded"]=encoder1.fit_transform(df["Objetivo do treino"])
df["lesao_encoded"]=encoder2.fit_transform(df[["Histórico de lesão"]])
df["nivel_encoded"]=encoder3.fit_transform(df["Nível"])


df.to_csv("dataset_atualizado.csv", index=False)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

df=pd.read_csv("dataset_atualizado.csv")

x=df[[
    "Tempo (min)",
    "Distância (km)",
    "lesao_encoded",
    "Pace (min/km)",
    "Atividades/semana",
    "objetivo_encoded"
]]

y=df[["nivel_encoded"]]

x_train,x_test,y_train,y_test= train_test_split(x,y, test_size=0.2, random_state=56)

modelo=RandomForestClassifier(n_estimators=5, random_state=56)

modelo.fit(x_train,y_train)

acuracia=modelo.score(x_test,y_test)
print(acuracia*100)
# Out:
# 99.9
# c:\Users\Sarah OA\OneDrive\Documentos\Faculdade\Aulas Algoritmos\Sistema-para-montagem-de-treinos-de-corrida\.venv\Lib\site-packages\sklearn\base.py:1389: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
